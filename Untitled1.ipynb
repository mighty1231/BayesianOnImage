# %%
import pymc3 as pm
from theano.compile.ops import as_op
import theano.tensor as tt
import numpy as np
import matplotlib.pyplot as plt
import cv2
import random
from skimage.measure import compare_ssim as ssim
# Out:
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
# C:\Anaconda3\envs\py35\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
sample = cv2.imread("sample/Lenna.png", cv2.IMREAD_GRAYSCALE)
plt.imshow(sample, cmap='gray', vmin=0, vmax=255)
# Out:
# 133
# 170

# %%
@as_op(itypes=[tt.lscalar, tt.lscalar, tt.lscalar, tt.lscalar, tt.lscalar], otypes=[tt.lscalar])
def rec_KL(lcx, lcy, rcx, rcy, co):
    w, h = sample.shape
    test = np.zeros((w, h), np.uint8)
    co = int(co)
    cv2.rectangle(test, (lcx, lcy), (rcx, rcy), co, -1)
    
    ep = 1
    sample_cp = np.copy(sample)

    kl = 0

    test[test == 0] += ep
    sample_cp[sample == 0] += ep

    for j in range(h):
        for i in range(w):
            kl += test[j][i] * np.log2(test[j][i] / sample_cp[j][i])
    kl = np.array(kl, dtype=np.int64)
    return kl

# %%
@as_op(itypes=[tt.lvector, tt.lvector, tt.lvector, tt.lvector, tt.lvector], otypes=[tt.lscalar])
def compute_ssim(lcx, lcy, rcx, rcy, co):
    w, h = sample.shape
    nr,  = lcx.shape
    
    test = np.zeros((w, h), np.uint8)
    for i in range(nr):
        cv2.rectangle(test, (lcx[i], lcy[i]), (rcx[i], rcy[i]), int(co[i]), -1)

    err = 100 * ssim(test, sample, data_range=test.max() - test.min())
    return np.array(err, dtype=np.int64)

# %%
@as_op(itypes=[tt.lvector, tt.lvector, tt.lvector, tt.lvector, tt.lvector], otypes=[tt.lscalar])
def compute_mse (lcx, lcy, rcx, rcy, co):
    w, h = sample.shape
    nr,  = lcx.shape
    
    test = np.zeros((w, h), np.uint8)
    for i in range(nr):
        cv2.rectangle(test, (lcx[i], lcy[i]), (rcx[i], rcy[i]), int(co[i]), -1)
    
    err = 100*np.sum((test.astype("float") - sample.astype("float"))**2)
    return np.array(err, dtype=np.int64)

# %%
num_rect = 1000

with pm.Model() as model:
    # Priors
    left_corner_x = pm.DiscreteUniform('left_corner_x', lower=0, upper=100, shape=num_rect)
    left_corner_y = pm.DiscreteUniform('left_corner_y', lower=0, upper=100, shape=num_rect)
    right_corner_x = pm.DiscreteUniform('right_corner_x', lower=0, upper=100, shape=num_rect)
    right_corner_y = pm.DiscreteUniform('right_corner_y', lower=0, upper=100, shape=num_rect)

    color = pm.DiscreteUniform('color', lower=0, upper=255, shape=num_rect)

    #obj = rec_KL(left_corner_x, left_corner_y, right_corner_x, right_corner_y, color)
    #obj = compute_ssim(left_corner_x, left_corner_y, right_corner_x, right_corner_y, color)
    obj = compute_mse(left_corner_x, left_corner_y, right_corner_x, right_corner_y, color)
    
    # Data likelihood
    objective_obs = pm.Normal('objective_obs', mu=obj, sd=1, observed=100)
    #objective_obs = pm.Poisson('objective', obj, observed=0)

    step = pm.Metropolis()

    # Initial values for stochastic nodes
    start = {'left_corner_x': np.random.randint(100, size=num_rect), 'left_corner_y': np.random.randint(100, size=num_rect),
             'right_corner_x': np.random.randint(100, size=num_rect), 'right_corner_y': np.random.randint(100, size=num_rect),
             'color': np.random.randint(255, size=num_rect)}

    tr = pm.sample(20000, start=start, step=[step], cores=1)
    #pm.traceplot(tr)

#print(pm.summary(tr))
plt.show()

lc_x, lc_y, rc_x, rc_y, c = [], [], [], [], []

for i in range(num_rect):
    lc_x.append(int(tr["left_corner_x"][:, i].mean()))
    lc_y.append(int(tr["left_corner_y"][:, i].mean()))
    rc_x.append(int(tr["right_corner_x"][:, i].mean()))
    rc_y.append(int(tr["right_corner_y"][:, i].mean()))
    c.append(int(tr["color"][:, i].mean()))

result = np.zeros((w, h))
print(c)
for i in range(num_rect):
    cv2.rectangle(result, (lc_x[i], lc_y[i]), (rc_x[i], rc_y[i]), c[i], -1)
plt.imshow(result, cmap='gray', vmin=0, vmax=255)
# Out:
# Sequential sampling (2 chains in 1 job)
# CompoundStep
# >Metropolis: [color]
# >Metropolis: [right_corner_y]
# >Metropolis: [right_corner_x]
# >Metropolis: [left_corner_y]
# >Metropolis: [left_corner_x]
# 100%|████████████████████████████████████████████████████████████████████████████| 20500/20500 [13:15<00:00, 25.77it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 20500/20500 [13:00<00:00, 26.25it/s]
# The gelman-rubin statistic is larger than 1.4 for some parameters. The sampler did not converge.
# [193, 16, 137, 107, 157, 139, 139, 245, 220, 234, 91, 13, 152, 185, 127, 101, 17, 74, 12, 218, 60, 104, 212, 90, 171, 228, 153, 10, 69, 83, 211, 235, 242, 186, 118, 221, 33, 226, 84, 28, 39, 136, 52, 158, 55, 31, 34, 100, 64, 18, 106, 138, 99, 101, 25, 217, 34, 174, 149, 189, 125, 88, 240, 110, 230, 81, 232, 52, 174, 45, 16, 121, 155, 96, 17, 243, 84, 114, 240, 11, 160, 58, 72, 152, 223, 82, 175, 105, 70, 108, 50, 203, 170, 214, 219, 9, 132, 233, 46, 190, 150, 77, 198, 39, 130, 200, 111, 241, 19, 144, 187, 198, 119, 22, 93, 225, 242, 187, 187, 39, 182, 95, 121, 165, 89, 138, 193, 208, 120, 230, 229, 99, 187, 73, 108, 55, 87, 212, 46, 26, 243, 216, 48, 125, 34, 231, 245, 24, 63, 46, 71, 82, 131, 212, 97, 246, 202, 209, 248, 239, 151, 132, 81, 24, 8, 171, 17, 116, 17, 165, 169, 145, 23, 94, 202, 115, 56, 59, 105, 22, 191, 241, 159, 66, 31, 246, 195, 43, 40, 22, 179, 24, 69, 199, 26, 166, 115, 196, 166, 41, 29, 241, 177, 177, 51, 154, 133, 46, 111, 170, 91, 115, 52, 19, 43, 43, 150, 200, 207, 146, 180, 182, 92, 232, 26, 207, 209, 5, 190, 234, 233, 80, 242, 158, 231, 47, 134, 74, 79, 186, 19, 106, 165, 43, 240, 224, 236, 56, 190, 9, 189, 187, 19, 225, 176, 63, 170, 230, 232, 70, 169, 174, 127, 120, 133, 93, 70, 237, 107, 22, 71, 11, 213, 213, 102, 69, 225, 18, 216, 235, 240, 240, 247, 200, 72, 195, 44, 213, 94, 215, 245, 168, 100, 137, 194, 121, 146, 70, 9, 15, 41, 18, 69, 169, 174, 140, 107, 180, 234, 168, 198, 163, 54, 20, 37, 70, 162, 180, 225, 26, 208, 58, 64, 150, 166, 68, 180, 141, 182, 13, 150, 174, 224, 231, 112, 193, 128, 198, 160, 36, 6, 79, 13, 143, 169, 151, 250, 112, 22, 32, 222, 64, 40, 40, 115, 129, 59, 156, 237, 248, 8, 26, 50, 136, 142, 34, 150, 88, 251, 193, 145, 141, 70, 153, 128, 174, 72, 19, 78, 14, 194, 142, 45, 60, 108, 188, 162, 112, 128, 180, 114, 224, 71, 212, 87, 248, 3, 10, 49, 200, 79, 154, 108, 12, 6, 236, 112, 38, 128, 175, 56, 115, 75, 57, 38, 19, 210, 238, 20, 35, 133, 203, 230, 113, 144, 31, 199, 151, 163, 245, 125, 50, 198, 181, 121, 57, 154, 83, 13, 74, 187, 54, 182, 18, 128, 30, 124, 9, 229, 9, 34, 99, 98, 67, 216, 246, 63, 54, 246, 5, 232, 106, 132, 206, 195, 183, 25, 218, 228, 82, 87, 150, 52, 245, 181, 18, 121, 229, 87, 223, 104, 223, 62, 11, 221, 44, 32, 113, 28, 248, 172, 141, 3, 215, 216, 144, 39, 134, 90, 67, 160, 3, 183, 42, 249, 135, 132, 58, 232, 89, 151, 108, 92, 92, 76, 166, 213, 156, 55, 46, 23, 101, 78, 133, 248, 156, 239, 196, 11, 129, 90, 143, 36, 153, 200, 183, 140, 19, 165, 124, 9, 125, 111, 226, 229, 135, 13, 30, 121, 151, 128, 244, 231, 220, 111, 168, 133, 167, 145, 46, 55, 68, 247, 41, 242, 24, 41, 22, 101, 156, 43, 23, 194, 29, 168, 148, 163, 197, 197, 116, 57, 11, 9, 68, 247, 220, 10, 97, 87, 211, 12, 121, 18, 10, 165, 95, 219, 157, 109, 245, 36, 127, 53, 32, 204, 222, 243, 142, 188, 25, 176, 124, 146, 117, 57, 143, 96, 219, 236, 44, 196, 205, 61, 85, 64, 244, 86, 176, 97, 62, 140, 79, 105, 177, 34, 118, 89, 243, 214, 30, 101, 232, 83, 47, 73, 46, 161, 15, 87, 37, 112, 205, 36, 9, 176, 109, 228, 167, 76, 38, 155, 78, 171, 124, 149, 222, 237, 96, 210, 17, 118, 45, 133, 142, 13, 109, 193, 239, 220, 65, 180, 116, 250, 217, 147, 59, 125, 4, 17, 3, 9, 27, 17, 127, 19, 203, 82, 189, 234, 126, 239, 30, 249, 54, 76, 113, 237, 203, 127, 160, 114, 109, 17, 123, 56, 40, 149, 8, 49, 129, 59, 61, 49, 126, 187, 87, 250, 191, 105, 81, 133, 108, 190, 38, 149, 109, 92, 118, 157, 15, 122, 27, 121, 191, 165, 13, 13, 155, 50, 240, 113, 113, 41, 213, 217, 10, 197, 131, 156, 235, 124, 44, 220, 132, 21, 234, 96, 56, 12, 45, 233, 149, 35, 208, 157, 123, 215, 223, 248, 22, 198, 241, 39, 72, 29, 131, 37, 204, 72, 119, 228, 62, 166, 108, 235, 99, 127, 185, 91, 111, 57, 160, 56, 89, 215, 126, 144, 9, 34, 33, 231, 134, 131, 107, 59, 119, 22, 73, 131, 230, 242, 160, 34, 235, 23, 64, 159, 83, 231, 187, 35, 220, 81, 195, 195, 23, 239, 212, 143, 93, 208, 96, 30, 164, 77, 235, 236, 12, 204, 146, 105, 101, 236, 124, 240, 182, 242, 211, 156, 65, 110, 98, 18, 90, 115, 126, 145, 244, 38, 20, 5, 117, 14, 69, 3 ...

# %%
print(tr["left_corner_x"][:, 0].mean())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-106-5435513b6b62> in <module>()
# ----> 1 print(tr["objective_obs"].mean())
#
# C:\Anaconda3\envs\py35\lib\site-packages\pymc3\backends\base.py in __getitem__(self, idx)
#     317         if var in self.stat_names:
#     318             return self.get_sampler_stats(var, burn=burn, thin=thin)
# --> 319         raise KeyError("Unknown variable %s" % var)
#     320
#     321     _attrs = set(['_straces', 'varnames', 'chains', 'stat_names',
#
# KeyError: 'Unknown variable objective_obs'

# %%
k = np.random.randint(10, size=2)
print(k.shape)
# Out:
# (2,)
